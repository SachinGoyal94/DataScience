# %% [markdown]
# ### 1 Missing Completely at Random, MCAR:
# Missing completely at random (MCAR) is a type of missing data mechanism in which the probability of a value being missing is unrelated to both the observed data and the missing data. In other words, if the data is MCAR, the missing values are randomly distributed throughout the dataset, and there is no systematic reason for why they are missing.
#
# For example, in a survey about the prevalence of a certain disease, the missing data might be MCAR if the survey participants with missing values for certain questions were selected randomly and their missing responses are not related to their disease status or any other variables measured in the survey.

# %% [markdown]
# ### 2. Missing at Random MAR:
# Missing at Random (MAR) is a type of missing data mechanism in which the probability of a value being missing depends only on the observed data, but not on the missing data itself. In other words, if the data is MAR, the missing values are systematically related to the observed data, but not to the missing data.
# Here are a few examples of missing at random:
#
# Income data: Suppose you are collecting income data from a group of people, but some participants choose not to report their income. If the decision to report or not report income is related to the participant's age or gender, but not to their income level, then the data is missing at random.
#
# Medical data: Suppose you are collecting medical data on patients, including their blood pressure, but some patients do not report their blood pressure. If the patients who do not report their blood pressure are more likely to be younger or have healthier lifestyles, but the missingness is not related to their actual blood pressure values, then the data is missing at random.

# %% [markdown]
# ## 3. Missing data not at random (MNAR)
# It is a type of missing data mechanism where the probability of missing values depends on the value of the missing data itself. In other words, if the data is MNAR, the missingness is not random and is dependent on unobserved or unmeasured factors that are associated with the missing values.
#
# For example, suppose you are collecting data on the income and job satisfaction of employees in a company. If employees who are less satisfied with their jobs are more likely to refuse to report their income, then the data is not missing at random. In this case, the missingness is dependent on job satisfaction, which is not directly observed or measured.

# %%
import pandas as pd

# %%
file=pd.read_csv('AWCustomers.csv')

# %%
file
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
file.shape
# Out:
# (18361, 24)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            18361 non-null  int64
#  1   Title                 101 non-null    object
#  2   FirstName             18361 non-null  object
#  3   MiddleName            10572 non-null  object
#  4   LastName              18361 non-null  object
#  5   Suffix                3 non-null      object
#  6   AddressLine1          18361 non-null  object
#  7   AddressLine2          311 non-null    object
#  8   City                  18361 non-null  object
#  9   StateProvinceName     18361 non-null  object
#  10  CountryRegionName     18361 non-null  object
#  11  PostalCode            18361 non-null  object
#  12  PhoneNumber           18361 non-null  object
#  13  BirthDate             18361 non-null  object
#  14  Education             18361 non-null  object
# ...

# %%
type(file)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.DataFrame(file)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
temp=pd.DataFrame(file)
temp.isnull()   #shows True for data where a cell contains null
# Out:
#        CustomerID  Title  FirstName  MiddleName  LastName  Suffix  \
# 0           False   True      False       False     False    True
# 1           False   True      False        True     False    True
# 2           False   True      False        True     False    True
# 3           False   True      False        True     False    True
# 4           False   True      False       False     False    True
# ...           ...    ...        ...         ...       ...     ...
# 18356       False   True      False       False     False    True
# 18357       False   True      False        True     False    True
# 18358       False   True      False        True     False    True
# 18359       False   True      False       False     False    True
# 18360       False   True      False        True     False    True
#
#        AddressLine1  AddressLine2   City  StateProvinceName  ...  Education  \
# 0             False          True  False              False  ...      False
# ...

# %%
temp.isnull().sum() #count of the null values in each column
# Out:
# CustomerID                  0
# Title                   18260
# FirstName                   0
# MiddleName               7789
# LastName                    0
# Suffix                  18358
# AddressLine1                0
# AddressLine2            18050
# City                        0
# StateProvinceName           0
# CountryRegionName           0
# PostalCode                  0
# PhoneNumber                 0
# BirthDate                   0
# Education                   0
# Occupation                  0
# Gender                      0
# MaritalStatus               0
# HomeOwnerFlag               0
# NumberCarsOwned             0
# NumberChildrenAtHome        0
# TotalChildren               0
# YearlyIncome                0
# LastUpdated                 0
# dtype: int64

# %% [markdown]
# Now to handle the missing values
# we can use drop the rows where null values are there or the columns
# but it will reduce the data which we do not want

# %%
temp.dropna().shape  #see if deleted column wise we will get 0 row as every column has atleast 1 null values
# Out:
# (0, 24)

# %%
temp.dropna(axis=0).shape  #see if deleted row wise we will get 0 row as every row has atleast 1 null values
# Out:
# (0, 24)

# %%
temp.shape
# Out:
# (18361, 24)

# %% [markdown]
# # HANDLING NULL VALUES

# %% [markdown]
# So it is not a reliable solution to remove the data entries to remove NULL values
#
# So either we can replace those null values with the Mean/Median/Mode
# as per our need
#
# or we can remove the data columns which is of no use for us
#
# For ex here if we are targeting a market where we want to sell a bicycle then
# these columns are of no use
# as we are name id is of no use as such
# 'CustomerID','FirstName','LastName','StateProvinceName','Suffix','Title','AddressLine2','Suffix','MiddleName'

# %%
file.drop(['CustomerID','FirstName','LastName','StateProvinceName','Suffix','Title','AddressLine2','Suffix','MiddleName'],axis=1,inplace=True)

# %%
file
# Out:
#                  AddressLine1            City CountryRegionName PostalCode  \
# 0          7090 C. Mount Hood      Wollongong         Australia       2500
# 1         3651 Willow Lake Rd         Shawnee            Canada    V9B 2C3
# 2      1774 Tice Valley Blvd.     West Covina     United States      91791
# 3             2103 Baldwin Dr       Liverpool    United Kingdom     L4 4HB
# 4             Am Gallberg 234           Werne           Germany      59368
# ...                       ...             ...               ...        ...
# 18356      6627 Camelback Ct.        Coronado     United States      92118
# 18357         9627 Kendall Rd  Port Macquarie         Australia       2444
# 18358       4364 Viera Avenue       Beaverton     United States      97005
# 18359  3866 Mt. Everest Court       Vancouver            Canada    V7L 4J4
# 18360     7870 Orangewood Dr.       Grossmont     United States      91941
#
# ...

# %% [markdown]
# See this time we are getting a data with no Null values and columns that are meaning ful for us

# %%
temp=pd.DataFrame(file)
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AddressLine1          18361 non-null  object
#  1   City                  18361 non-null  object
#  2   CountryRegionName     18361 non-null  object
#  3   PostalCode            18361 non-null  object
#  4   PhoneNumber           18361 non-null  object
#  5   BirthDate             18361 non-null  object
#  6   Education             18361 non-null  object
#  7   Occupation            18361 non-null  object
#  8   Gender                18361 non-null  object
#  9   MaritalStatus         18361 non-null  object
#  10  HomeOwnerFlag         18361 non-null  int64
#  11  NumberCarsOwned       18361 non-null  int64
#  12  NumberChildrenAtHome  18361 non-null  int64
#  13  TotalChildren         18361 non-null  int64
#  14  YearlyIncome          18361 non-null  int64
# ...

# %%
temp.describe()
# Out:
#        HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# count   18361.000000     18361.000000          18361.000000   18361.000000
# mean        0.610588         1.270301              0.338162       0.850389
# std         0.487630         0.913989              0.568957       0.927315
# min         0.000000         0.000000              0.000000       0.000000
# 25%         0.000000         1.000000              0.000000       0.000000
# 50%         1.000000         1.000000              0.000000       0.000000
# 75%         1.000000         2.000000              1.000000       2.000000
# max         1.000000         5.000000              3.000000       3.000000
#
#         YearlyIncome
# count   18361.000000
# mean    72754.779642
# std     30686.014313
# min     25435.000000
# 25%     53312.000000
# 50%     61851.000000
# 75%     87410.000000
# max    139115.000000

# %%
import matplotlib.pyplot as plt
plt.hist(temp['YearlyIncome'],bins=10)
plt.show()

# %% [markdown]
# # NORMALIZATION

# %% [markdown]
# now what if i want to normalise the data now
# NORMALISATION-->Our data has larger values in column income and smaller in age so if we usee knn or any algo it may overlook for income only it has larger scale so to avoid this paritality ,we should normalize our Data

# %%
normalised_temp=temp.select_dtypes(include=['number']).columns
normalised_temp
# Out:
# Index(['HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome',
#        'TotalChildren', 'YearlyIncome'],
#       dtype='object')

# %%
temp['YearlyIncome']
# Out:
# 0         81916
# 1         81076
# 2         86387
# 3         61481
# 4         51804
#           ...
# 18356     52953
# 18357     60992
# 18358     51859
# 18359     87177
# 18360    136856
# Name: YearlyIncome, Length: 18361, dtype: int64

# %% [markdown]
# | Feature             | Min–Max Normalization  | Z-score Standardization |
# | ------------------- | ---------------------- | ----------------------- |
# | Range               | \[0, 1]                | No fixed range          |
# | Uses                | Distance-based methods | Variance-based methods  |
# | Outlier Sensitivity | Highly sensitive       | Less sensitive          |
# | Mean after scaling  | \~0.5                  | 0                       |
# | Std after scaling   | Depends on range       | 1                       |

# %% [markdown]
# MIN_MAX Normalization values =[0,1]

# %%
normalised_temp_df[normalised_temp]=((temp[normalised_temp]-temp[normalised_temp].min())/(temp[normalised_temp].max()-temp[normalised_temp].min()))
normalised_temp_df
# Out:
#        HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# 0                1.0              0.6              0.000000       0.333333
# 1                1.0              0.4              0.333333       0.666667
# 2                0.0              0.6              0.000000       0.000000
# 3                1.0              0.4              0.333333       0.666667
# 4                1.0              0.2              0.000000       0.000000
# ...              ...              ...                   ...            ...
# 18356            0.0              0.2              0.000000       0.666667
# 18357            0.0              0.4              0.000000       0.000000
# 18358            0.0              0.4              0.000000       0.000000
# 18359            0.0              0.0              0.000000       0.000000
# 18360            1.0              0.4              0.000000       0.000000
#
#        YearlyIncome
# 0          0.496842
# 1          0.489453
# ...

# %%
plt.hist(normalised_temp_df['YearlyIncome'],bins=10)
plt.show()

# %% [markdown]
# Z-Score Standarization

# %%
normalised_temp_df[normalised_temp]=((temp[normalised_temp]-temp[normalised_temp].min())/temp[normalised_temp].std())
normalised_temp_df
# Out:
#        HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# 0           2.050734         3.282316              0.000000       1.078382
# 1           2.050734         2.188211              1.757603       2.156763
# 2           0.000000         3.282316              0.000000       0.000000
# 3           2.050734         2.188211              1.757603       2.156763
# 4           2.050734         1.094105              0.000000       0.000000
# ...              ...              ...                   ...            ...
# 18356       0.000000         1.094105              0.000000       2.156763
# 18357       0.000000         2.188211              0.000000       0.000000
# 18358       0.000000         2.188211              0.000000       0.000000
# 18359       0.000000         0.000000              0.000000       0.000000
# 18360       2.050734         2.188211              0.000000       0.000000
#
#        YearlyIncome
# 0          1.840610
# 1          1.813236
# ...

# %%
plt.hist(normalised_temp_df['YearlyIncome'],bins=10)
plt.show()
